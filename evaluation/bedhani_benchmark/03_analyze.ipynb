# %%
from aemeasure import read_as_pandas_table, Database

# %%
Database("results").compress()

# %%
data = read_as_pandas_table("results")

# %%
import pandas as pd
pd.set_option('display.max_rows', 600)
data["n_"] = data["instance"].apply(lambda s: s.split("-")[-2])
data[["instance", "radius", "runtime","n_"]].sort_values(by="runtime").groupby(["instance", "radius"]).min().reset_index().groupby(["n_", "radius"])[["runtime"]].max()
# Out:
#               runtime
# n_ radius
# 06 0.25      0.014266
#    0.50      0.012002
# 08 0.25      0.057498
#    0.50      0.021561
# 10 0.25      0.078434
#    0.50      0.055793
# 12 0.25      0.258536
#    0.50      0.214349
# 14 0.25      0.377225
#    0.50      0.237332
# 16 0.25      0.992758
#    0.50      0.464283
# 18 0.25      0.752269
#    0.50      0.614506
# 20 0.25      2.897311
#    0.50      1.217872
# 25 0.25     40.312554
#    0.50      6.952237
# 30 0.25    200.467483
#    0.50     15.176578
