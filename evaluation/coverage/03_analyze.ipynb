# %%
from aemeasure import read_as_pandas_table

# %%
data = read_as_pandas_table("results")
data
# Out:
#                                 instance            ub  ...  stdout  stderr
# 0   srpg_octa0000092/upper_bound_46.json  1.117304e-09  ...
# 1   srpg_octa0000092/upper_bound_57.json  1.633402e-10  ...
# 2   srpg_octa0000092/upper_bound_63.json  3.397230e-09  ...
# 3   srpg_octa0000092/upper_bound_61.json  1.305448e-08  ...
# 4   srpg_octa0000092/upper_bound_38.json  4.469163e-09  ...
# ..                                   ...           ...  ...     ...     ...
# 67  srpg_octa0000092/upper_bound_12.json  8.717762e-09  ...
# 68  srpg_octa0000092/upper_bound_36.json  1.574311e-10  ...
# 69  srpg_octa0000092/upper_bound_29.json  1.277475e+01  ...
# 70  srpg_octa0000092/upper_bound_19.json  3.238773e-10  ...
# 71  srpg_octa0000092/upper_bound_39.json  2.148115e-10  ...
#
# [72 rows x 13 columns]

# %%
import pandas as pd
pd.set_option('display.max_rows', 100)
data[["instance", "runtime"]].sort_values(by="runtime")
# Out:
#                                 instance    runtime
# 54  srpg_octa0000092/upper_bound_30.json   0.001643
# 14  srpg_octa0000092/upper_bound_25.json   0.001662
# 59  srpg_octa0000092/upper_bound_49.json   0.001740
# 70  srpg_octa0000092/upper_bound_19.json   0.001744
# 4   srpg_octa0000092/upper_bound_38.json   0.001774
# 28  srpg_octa0000092/upper_bound_53.json   0.001821
# 55   srpg_octa0000092/upper_bound_7.json   0.001834
# 38  srpg_octa0000092/upper_bound_64.json   0.001835
# 30  srpg_octa0000092/upper_bound_51.json   0.001943
# 68  srpg_octa0000092/upper_bound_36.json   0.001996
# 71  srpg_octa0000092/upper_bound_39.json   0.002039
# 43  srpg_octa0000092/upper_bound_23.json   0.002068
# 48  srpg_octa0000092/upper_bound_56.json   0.002186
# 56  srpg_octa0000092/upper_bound_50.json   0.002383
# 46  srpg_octa0000092/upper_bound_42.json   0.002497
# 65  srpg_octa0000092/upper_bound_28.json   0.002520
# 15  srpg_octa0000092/upper_bound_68.json   0.002586
# 57  srpg_octa0000092/upper_bound_44.json   0.002624
# 18  srpg_octa0000092/upper_bound_11.json   0.002642
# 60  srpg_octa0000092/upper_bound_16.json   0.002677
# 6   srpg_octa0000092/upper_bound_20.json   0.002685
# 40  srpg_octa0000092/upper_bound_59.json   0.002693
# 5   srpg_octa0000092/upper_bound_67.json   0.002748
# 24  srpg_octa0000092/upper_bound_65.json   0.002762
# 67  srpg_octa0000092/upper_bound_12.json   0.002806
# 64  srpg_octa0000092/upper_bound_66.json   0.002859
# 62  srpg_octa0000092/upper_bound_37.json   0.002935
# 2   srpg_octa0000092/upper_bound_63.json   0.002954
# 49  srpg_octa0000092/upper_bound_22.json   0.002960
# 33  srpg_octa0000092/upper_bound_18.json   0.002980
# 12  srpg_octa0000092/upper_bound_34.json   0.003017
# 3   srpg_octa0000092/upper_bound_61.json   0.003046
# 10  srpg_octa0000092/upper_bound_40.json   0.003080
# 0   srpg_octa0000092/upper_bound_46.json   0.003097
# 20  srpg_octa0000092/upper_bound_24.json   0.003116
# 25  srpg_octa0000092/upper_bound_43.json   0.003145
# 8   srpg_octa0000092/upper_bound_41.json   0.003167
# 26  srpg_octa0000092/upper_bound_62.json   0.003169
# 16  srpg_octa0000092/upper_bound_21.json   0.003202
# 22   srpg_octa0000092/upper_bound_8.json   0.003241
# 21  srpg_octa0000092/upper_bound_71.json   0.003263
# 19  srpg_octa0000092/upper_bound_14.json   0.003299
# 7   srpg_octa0000092/upper_bound_69.json   0.003306
# 35  srpg_octa0000092/upper_bound_45.json   0.003363
# 66  srpg_octa0000092/upper_bound_32.json   0.003431
# 37  srpg_octa0000092/upper_bound_10.json   0.003463
# 63  srpg_octa0000092/upper_bound_55.json   0.003632
# 1   srpg_octa0000092/upper_bound_57.json   0.003641
# 51  srpg_octa0000092/upper_bound_15.json   0.003656
# 58  srpg_octa0000092/upper_bound_47.json   0.003883
# 53  srpg_octa0000092/upper_bound_58.json   0.003976
# 39  srpg_octa0000092/upper_bound_13.json   0.004071
# 29  srpg_octa0000092/upper_bound_17.json   0.004236
# 41   srpg_octa0000092/upper_bound_4.json   0.004315
# 27  srpg_octa0000092/upper_bound_26.json   0.004363
# 42  srpg_octa0000092/upper_bound_60.json   0.004415
# 23   srpg_octa0000092/upper_bound_9.json   0.004464
# 11   srpg_octa0000092/upper_bound_5.json   0.004493
# 69  srpg_octa0000092/upper_bound_29.json   0.004619
# 50  srpg_octa0000092/upper_bound_52.json   0.004706
# 45   srpg_octa0000092/upper_bound_6.json   0.004996
# 52  srpg_octa0000092/upper_bound_33.json   0.005057
# 9    srpg_octa0000092/lower_bound_0.json   0.005651
# 47  srpg_octa0000092/upper_bound_54.json   0.005834
# 36  srpg_octa0000092/upper_bound_35.json   0.006090
# 17  srpg_octa0000092/upper_bound_31.json   0.006279
# 61  srpg_octa0000092/upper_bound_27.json   0.009501
# 34  srpg_octa0000092/upper_bound_48.json   0.011539
# 31  srpg_octa0000092/upper_bound_70.json   0.018291
# 13   srpg_octa0000092/upper_bound_3.json   0.230112
# 32   srpg_octa0000092/lower_bound_1.json   0.872747
# 44   srpg_octa0000092/lower_bound_2.json  21.763112
