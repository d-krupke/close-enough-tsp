# %%
from cetsp_bnb2.core import (Instance, Circle, Point, plot_instance)

# %%
import gzip
import json

with open("00_instances/benchmark.json.gz", "rb") as f:
    instances = json.loads(gzip.decompress(f.read()).decode("utf-8"))

instance_names = list(instances.keys())

# %%
import matplotlib.pyplot as plt
import random
for i in range(5):
    instance_name = random.choice(instance_names)
    instance = Instance([Circle(Point(d["x"], d['y']), d["r"]) for d in instances[instance_name]["disks"]])
    fig, ax = plt.subplots(figsize=(10, 10))
    plt.title(instance_name)
    plot_instance(ax, instance)
    plt.show()
# Out:
# Removed implicit circle (76.6865, 13.8696)
# Removed implicit circle (90.8182, 18.2159)
# Removed implicit circle (75.0077, 29.5014)
# Removed implicit circle (77.0304, 15.5107)
# Removed implicit circle (82.0189, 31.5854)
# Removed implicit circle (71.295, 19.8608)
# Removed implicit circle (2.88194, 70.7873)
# Removed implicit circle (87.039, 21.0955)
# Removed implicit circle (70.7195, 19.5494)
# Removed implicit circle (9.4, 0.8)
# Removed implicit circle (5.4, 13.2)
# Removed implicit circle (2.4, 15.3)
# Removed implicit circle (12.7, 27.3)
# Removed implicit circle (6.3, 12.4)
# Removed implicit circle (0.6, 24.9)
# Removed implicit circle (12.3, 1.5)
# Removed implicit circle (3.4, 22.5)
# Removed implicit circle (12.5, 25.3)
# Removed implicit circle (1.5, 24.6)
# Removed implicit circle (12.5, 19.5)
# Removed implicit circle (9.4, 28.4)
# Removed implicit circle (2.7, 13.4)
# Removed implicit circle (2.5, 19.5)
# Removed implicit circle (1.5, 21.3)
# Removed implicit circle (6.4, 16.8)
# Removed implicit circle (11.3, 19.3)
# Removed implicit circle (1.3, 9.5)
# Removed implicit circle (11.3, 3.1)
# Removed implicit circle (3.3, 21.4)
# Removed implicit circle (3.3, 28.4)
# Removed implicit circle (0.7, 15.2)
# Removed implicit circle (6.6, 6.8)
# Removed implicit circle (2.6, 23.5)
# Removed implicit circle (4.3, 22.7)
# Removed implicit circle (5.3, 17.4)
# Removed implicit circle (7.4, 6.7)
# Removed implicit circle (7.3, 24.7)
# Removed implicit circle (2.4, 11.2)
# Removed implicit circle (2.3, 0.9)
# Removed implicit circle (6.4, 5.4)
# Removed implicit circle (0.6, 8.4)
# Removed implicit circle (10.4, 25.6)
# Removed implicit circle (6.6, 19.2)
# Removed implicit circle (9.8, 10.8)
# Removed implicit circle (12.7, 14.8)
# Removed implicit circle (7.4, 3.2)
# Removed implicit circle (8.3, 8.9)
# Removed implicit circle (12.6, 10.9)
# Removed implicit circle (5.5, 14.6)
# Removed implicit circle (11.7, 11.5)
# Removed implicit circle (3.3, 24.6)
# Removed implicit circle (9.3, 18.5)
# Removed implicit circle (8.7, 26.4)
# Removed implicit circle (5.3, 2.5)
# Removed implicit circle (9.4, 20.9)
# Removed implicit circle (2.6, 5)
# Removed implicit circle (4.3, 11.2)
# Removed implicit circle (1.6, 18.8)
# Removed implicit circle (1.7, 1.2)
# Removed implicit circle (10.3, 12.6)
# Removed implicit circle (2.5, 16.5)
# Removed implicit circle (4.2, 3.4)
# Removed implicit circle (7.7, 9.3)
# Removed implicit circle (12.5, 3.4)
# Removed implicit circle (10.6, 19.2)
# Removed implicit circle (2.6, 25.5)
# Removed implicit circle (2.4, 26.7)
# Removed implicit circle (1.6, 14.7)
# Removed implicit circle (8.7, 23)
# Removed implicit circle (6.3, 15.5)
# Removed implicit circle (2.5, 9.4)
# Removed implicit circle (8.8, 4.9)
# Removed implicit circle (6.4, 11.2)
# Removed implicit circle (11.6, 13)
# Removed implicit circle (10.7, 6.5)
# Removed implicit circle (8.7, 24.9)
# Removed implicit circle (0.7, 11.4)
# Removed implicit circle (9.4, 9.5)
# Removed implicit circle (2.3, 28.7)
# Removed implicit circle (9.8, 5)
# Removed implicit circle (8.7, 17.3)
# Removed implicit circle (12.3, 9.3)
# Removed implicit circle (8.6, 10.7)
# Removed implicit circle (0.6, 22.9)
# Removed implicit circle (11.5, 20.6)
# Removed implicit circle (11.3, 24.6)
# Removed implicit circle (12.5, 6.8)
# Removed implicit circle (5.5, 22.5)
# Removed implicit circle (1.5, 3.2)
# Removed implicit circle (6.7, 28.8)
# Removed implicit circle (11.7, 22.5)
# Removed implicit circle (7.5, 0.7)
# Removed implicit circle (7.5, 4.4)
# Removed implicit circle (11.4, 16.9)
# Removed implicit circle (10.5, 22.8)
# Removed implicit circle (5.3, 21.1)
# Removed implicit circle (7.5, 23.4)
# Removed implicit circle (10.4, 21.5)
# Removed implicit circle (4.4, 13.1)
# Removed implicit circle (9.4, 24.5)
# Removed implicit circle (8.7, 15.4)
# Removed implicit circle (9.5, 17.4)
# Removed implicit circle (3.7, 18.6)
# Removed implicit circle (10.6, 26.4)
# Removed implicit circle (0.6, 7.5)
# Removed implicit circle (10.4, 29.1)
# Removed implicit circle (7.4, 26.5)
# Removed implicit circle (6.6, 1.6)
# Removed implicit circle (8.2, 13.4)
# Removed implicit circle (10.4, 15.1)
# Removed implicit circle (11.7, 15.3)
# Removed implicit circle (7.3, 11.2)
# Removed implicit circle (3.6, 5.4)
# Removed implicit circle (0.3, 1.2)
# Removed implicit circle (1.7, 12.5)
# Removed implicit circle (3.4, 1.1)
# Removed implicit circle (0.5, 20.7)
# Removed implicit circle (9.4, 7.4)
# Removed implicit circle (0.3, 16.4)
# Removed implicit circle (10.4, 2.5)
# Removed implicit circle (9.5, 2.8)
# Removed implicit circle (1.6, 27.4)
# Removed implicit circle (7.6, 17.1)
# Removed implicit circle (10.6, 16.8)
# Removed implicit circle (0.3, 19)
# Removed implicit circle (5.3, 9.5)
# Removed implicit circle (6.5, 24.8)
# Removed implicit circle (5.4, 26.6)
# Removed implicit circle (6.3, 8.6)
# Removed implicit circle (6.4, 21.3)
# Removed implicit circle (0.3, 4.8)
# Removed implicit circle (11.7, 6.5)
# Removed implicit circle (4.7, 1.1)
# Removed implicit circle (4.5, 15.4)
# Removed implicit circle (7.4, 21.2)
# Removed implicit circle (3.3, 3.4)
# Removed implicit circle (12.7, 20.9)
# Removed implicit circle (11.5, 9.5)
# Removed implicit circle (8.7, 29.3)
# Removed implicit circle (9.5, 27.1)
# Removed implicit circle (4.3, 20.6)
# Removed implicit circle (3.7, 26.6)
# Removed implicit circle (4.5, 26.7)
# Removed implicit circle (4.8, 5)
# Removed implicit circle (1.6, 17.2)
# Removed implicit circle (6.7, 22.9)
# Removed implicit circle (1.5, 4.6)
# Removed implicit circle (1.7, 29.4)
# Removed implicit circle (3.6, 7.3)
# Removed implicit circle (3.6, 10.8)
# Removed implicit circle (1.3, 22.7)
# Removed implicit circle (5.8, 25.2)
# Removed implicit circle (0.7, 28.7)
# Removed implicit circle (8.5, 18.8)
# Removed implicit circle (7.7, 19.2)
# Removed implicit circle (12.7, 4.9)
# Removed implicit circle (5.4, 1.2)
# Removed implicit circle (7.7, 12.7)
# Removed implicit circle (10.7, 0.9)
# Removed implicit circle (7.5, 15.1)
# Removed implicit circle (4.7, 24.8)
# Removed implicit circle (8.4, 21.2)
# Removed implicit circle (5.4, 4.6)
# Removed implicit circle (4.4, 18.9)
# Removed implicit circle (5.3, 29.5)
# Removed implicit circle (10.4, 11.3)
# Removed implicit circle (8.5, 6.5)
# Removed implicit circle (5.6, 10.5)
# Removed implicit circle (11.4, 29.4)

# %%
from cetsp_bnb2.core import optimize, plot_solution

instance_name = "concentricCircles2"
instance = Instance([Circle(Point(d["x"], d['y']), d["r"]) for d in instances[instance_name]["disks"]])

fig, ax = plt.subplots(figsize=(10, 10))
plt.title(instance_name)
plot_instance(ax, instance)
plt.show()

sol = optimize(instance, optimality_gap=0.001, feasibility_tol=0.0001)
fig, ax = plt.subplots(figsize=(10, 10))
plt.title(instance_name)
plot_solution(ax, instance, sol[0])
plt.show()
# Out:
# Failed to import Concorde (dlopen(/Users/krupke/Repositories/pyconcorde/concorde/_concorde.cpython-310-darwin.so, 0x0002): symbol not found in flat namespace '_QSadd_cols'). Please try to install it via `pip install git+https://github.com/jvkersch/pyconcorde`. Unfortunately, this does not work on all platforms.
# Failed to compute initial solution with Concorde (No Concorde available.). Falling back to a simple 2-opt heuristic. To prevent this, set `fallback_if_no_concorde=False`.
# Using node simplification.
# Exploring on 8 threads
# Branching on farthest circle.
# Using GlobalConvexHullRule
# Using DfsBfs search
# py_callback 0x7ff7bf75a060
# Starting with root node of size 20
# i	LB	|	UB	|	Time
# 1	129.884	|	160.33	|	0.03s
# 2	129.884	|	160.33	|	0.053s
# 3	129.884	|	160.33	|	0.088s
# 4	129.884	|	160.33	|	0.114s
# 5	129.884	|	160.33	|	0.137s
# 6	129.884	|	160.33	|	0.165s
# 7	129.884	|	160.33	|	0.196s
# 8	129.884	|	160.33	|	0.226s
# 9	129.884	|	160.33	|	0.261s
# 10	129.884	|	160.33	|	0.309s
# 20	129.884	|	154.53	|	0.563s
# 30	129.884	|	154.53	|	0.816s
# 40	129.884	|	154.53	|	1.099s
# 50	132.189	|	154.53	|	1.364s
# 60	132.189	|	154.53	|	1.568s
# 70	132.189	|	154.53	|	1.766s
# 80	132.286	|	154.53	|	1.965s
# 90	132.286	|	154.53	|	2.177s
# 100	132.286	|	154.53	|	2.41s
# 200	134.576	|	153.325	|	4.935s
# 300	136.084	|	153.325	|	7.03s
# 400	136.978	|	153.325	|	9.016s
# 500	137.708	|	153.325	|	11.291s
# 600	138.396	|	153.325	|	13.397s
# 700	139.04	|	153.325	|	15.39s
# 800	139.53	|	153.325	|	17.468s
# 900	139.847	|	153.325	|	19.431s
# 1000	140.213	|	153.325	|	21.473s
# 2000	142.42	|	153.325	|	42.922s
# Timeout.
# ---------------
# 2733	143.403	|	153.325
# 2733 iterations with 2296 nodes explored and 2294 branches.

# %%
instances[instance_name]
# Out:
# {'disks': [{'x': 19.5535, 'y': 32.6157, 'r': 0.0, 'meta': 'depot'},
#   {'x': 70.55475, 'y': 53.342402, 'r': 20.0},
#   {'x': 57.95186, 'y': 28.956245, 'r': 20.0},
#   {'x': 30.1948, 'y': 77.47401, 'r': 20.0},
#   {'x': 1.401765, 'y': 76.07236, 'r': 20.0},
#   {'x': 81.449, 'y': 70.90379, 'r': 20.0},
#   {'x': 4.535275, 'y': 41.40327, 'r': 20.0},
#   {'x': 86.26193, 'y': 79.048, 'r': 20.0},
#   {'x': 37.353615, 'y': 96.195315, 'r': 20.0},
#   {'x': 87.144585, 'y': 5.62369, 'r': 20.0},
#   {'x': 94.955665, 'y': 36.40187, 'r': 20.0},
#   {'x': 52.486843, 'y': 76.711165, 'r': 20.0},
#   {'x': 5.35045, 'y': 59.245825, 'r': 20.0},
#   {'x': 46.870011, 'y': 29.816545, 'r': 20.0},
#   {'x': 62.26967, 'y': 64.78212, 'r': 20.0},
#   {'x': 26.379295, 'y': 27.934205, 'r': 20.0},
#   {'x': 82.980165, 'y': 82.460215, 'r': 20.0},
#   {'x': 58.9163, 'y': 98.60932, 'r': 20.0},
#   {'x': 91.09643, 'y': 22.6866, 'r': 20.0},
#   {'x': 69.51155, 'y': 98.000325, 'r': 20.0},
#   {'x': 24.393135, 'y': 53.387308, 'r': 20.0},
#   {'x': 10.636965, 'y': 99.941455, 'r': 20.0},
#   {'x': 67.61759, 'y': 1.570395, 'r': 20.0},
#   {'x': 57.51838, 'y': 10.00522, 'r': 20.0},
#   {'x': 10.302265, 'y': 79.88844, 'r': 20.0},
#   {'x': 28.448025, 'y': 4.56492, 'r': 20.0},
#   {'x': 29.577285, 'y': 38.20107, 'r': 20.0},
#   {'x': 30.09705, 'y': 94.85711, 'r': 20.0},
#   {'x': 97.982935, 'y': 40.137435, 'r': 20.0},
#   {'x': 27.827995, 'y': 16.04415, 'r': 20.0},
#   {'x': 16.28216, 'y': 64.658715, 'r': 20.0},
#   {'x': 41.00732, 'y': 41.27668, 'r': 20.0},
#   {'x': 71.273045, 'y': 32.62062, 'r': 20.0},
#   {'x': 63.31789, 'y': 20.756115, 'r': 20.0},
#   {'x': 18.601355, 'y': 58.3359, 'r': 20.0},
#   {'x': 8.071465, 'y': 45.7971455, 'r': 20.0},
#   {'x': 90.572985, 'y': 26.136825, 'r': 20.0},
#   {'x': 78.52122, 'y': 37.890255, 'r': 20.0},
#   {'x': 28.966505, 'y': 91.93771, 'r': 20.0},
#   {'x': 63.17424, 'y': 62.764205, 'r': 20.0},
#   {'x': 42.845635, 'y': 9.79738, 'r': 20.0},
#   {'x': 56.10401, 'y': 69.44853, 'r': 20.0},
#   {'x': 91.37176, 'y': 83.481715, 'r': 20.0},
#   {'x': 2.26292, 'y': 54.336059, 'r': 20.0},
#   {'x': 91.6164, 'y': 43.026115, 'r': 20.0},
#   {'x': 67.794775, 'y': 0.2453923, 'r': 20.0},
#   {'x': 51.37375, 'y': 46.298003, 'r': 20.0},
#   {'x': 35.347265, 'y': 40.483415, 'r': 20.0},
#   {'x': 26.97316, 'y': 5.55935, 'r': 20.0},
#   {'x': 24.384515, 'y': 97.907795, 'r': 20.0},
#   {'x': 6.091625, 'y': 39.029145, 'r': 20.0},
#   {'x': 36.49954, 'y': 48.989475, 'r': 20.0},
#   {'x': 15.566305, 'y': 47.445917, 'r': 20.0},
#   {'x': 25.726765, 'y': 62.875185, 'r': 20.0},
#   {'x': 54.207021, 'y': 15.63022, 'r': 20.0},
#   {'x': 93.854515, 'y': 65.44994, 'r': 20.0},
#   {'x': 50.608737, 'y': 39.047145, 'r': 20.0},
#   {'x': 10.737535, 'y': 78.399525, 'r': 20.0},
#   {'x': 45.96408, 'y': 75.36881, 'r': 20.0},
#   {'x': 59.609455, 'y': 83.27302, 'r': 20.0},
#   {'x': 1.875835, 'y': 21.036865, 'r': 20.0},
#   {'x': 7.39533, 'y': 10.545265, 'r': 20.0},
#   {'x': 33.169445, 'y': 12.82499, 'r': 20.0},
#   {'x': 0.024125, 'y': 3.6794065, 'r': 20.0},
#   {'x': 65.705495, 'y': 54.4013975, 'r': 20.0},
#   {'x': 82.741185, 'y': 8.18936, 'r': 20.0},
#   {'x': 19.19225, 'y': 67.891335, 'r': 20.0},
#   {'x': 45.420784, 'y': 35.70231, 'r': 20.0},
#   {'x': 14.99811, 'y': 70.439575, 'r': 20.0},
#   {'x': 92.878595, 'y': 53.021252, 'r': 20.0},
#   {'x': 8.96414, 'y': 75.77293, 'r': 20.0},
#   {'x': 40.184205, 'y': 46.1874365, 'r': 20.0},
#   {'x': 49.216563, 'y': 20.76273, 'r': 20.0},
#   {'x': 32.973595, 'y': 9.54291, 'r': 20.0},
#   {'x': 58.979255, 'y': 16.987345, 'r': 20.0},
#   {'x': 92.761655, 'y': 9.792985, 'r': 20.0},
#   {'x': 44.38625, 'y': 27.294685, 'r': 20.0},
#   {'x': 87.254685, 'y': 75.06877, 'r': 20.0},
#   {'x': 27.294235, 'y': 67.36467, 'r': 20.0},
#   {'x': 25.662895, 'y': 8.989655, 'r': 20.0},
#   {'x': 3.09506, 'y': 32.271765, 'r': 20.0},
#   {'x': 79.01289, 'y': 29.7258, 'r': 20.0},
#   {'x': 23.528225, 'y': 48.047471, 'r': 20.0},
#   {'x': 25.46019, 'y': 34.06066, 'r': 20.0},
#   {'x': 4.493385, 'y': 48.2428075, 'r': 20.0},
#   {'x': 20.60172, 'y': 86.45345, 'r': 20.0},
#   {'x': 58.86286, 'y': 75.490835, 'r': 20.0},
#   {'x': 92.788305, 'y': 33.10169, 'r': 20.0},
#   {'x': 54.294115, 'y': 8.069135, 'r': 20.0},
#   {'x': 63.437195, 'y': 41.00367, 'r': 20.0},
#   {'x': 96.04228, 'y': 11.46233, 'r': 20.0},
#   {'x': 92.344515, 'y': 62.02096, 'r': 20.0},
#   {'x': 34.77264, 'y': 14.924575, 'r': 20.0},
#   {'x': 47.997827, 'y': 21.94091, 'r': 20.0},
#   {'x': 99.37313, 'y': 13.042045, 'r': 20.0},
#   {'x': 2.888575, 'y': 34.539165, 'r': 20.0},
#   {'x': 54.766852, 'y': 92.295455, 'r': 20.0},
#   {'x': 53.824634, 'y': 40.64213, 'r': 20.0},
#   {'x': 84.72455, 'y': 82.62255, 'r': 20.0},
#   {'x': 67.24276, 'y': 72.18951, 'r': 20.0},
#   {'x': 99.67714, 'y': 33.98061, 'r': 20.0},
#   {'x': 49.52113, 'y': 41.29678, 'r': 20.0},
#   {'x': 69.52818, 'y': 17.90893, 'r': 20.0},
#   {'x': 42.291825, 'y': 54.317701, 'r': 20.0},
#   {'x': 81.466395, 'y': 54.091358, 'r': 20.0},
#   {'x': 42.753335, 'y': 50.906813, 'r': 20.0},
#   {'x': 22.77816, 'y': 61.91876, 'r': 20.0},
#   {'x': 48.983044, 'y': 68.08194, 'r': 20.0},
#   {'x': 88.660005, 'y': 37.051535, 'r': 20.0},
#   {'x': 30.249755, 'y': 29.28668, 'r': 20.0},
#   {'x': 15.031135, 'y': 2.9821155, 'r': 20.0},
#   {'x': 22.32618, 'y': 58.45293, 'r': 20.0},
#   {'x': 36.34587, 'y': 87.597465, 'r': 20.0},
#   {'x': 47.801417, 'y': 19.06334, 'r': 20.0},
#   {'x': 68.40623, 'y': 74.741575, 'r': 20.0},
#   {'x': 61.393495, 'y': 78.21387, 'r': 20.0},
#   {'x': 16.17437, 'y': 80.77798, 'r': 20.0},
#   {'x': 20.26183, 'y': 95.676245, 'r': 20.0},
#   {'x': 6.5851, 'y': 6.152225, 'r': 20.0},
#   {'x': 79.319755, 'y': 37.96047, 'r': 20.0},
#   {'x': 46.358401, 'y': 11.954405, 'r': 20.0},
#   {'x': 11.54701, 'y': 17.37734, 'r': 20.0},
#   {'x': 4.81189, 'y': 71.48163, 'r': 20.0},
#   {'x': 53.302235, 'y': 56.10093, 'r': 20.0},
#   {'x': 21.673354, 'y': 6.8005655, 'r': 20.0},
#   {'x': 74.635475, 'y': 75.231085, 'r': 20.0},
#   {'x': 39.89323, 'y': 90.309885, 'r': 20.0},
#   {'x': 74.60069, 'y': 8.85595, 'r': 20.0},
#   {'x': 63.457115, 'y': 71.302795, 'r': 20.0},
#   {'x': 1.56824, 'y': 43.114435, 'r': 20.0},
#   {'x': 40.19826, 'y': 27.52955, 'r': 20.0},
#   {'x': 98.53739, 'y': 80.25874, 'r': 20.0},
#   {'x': 69.610075, 'y': 41.75992, 'r': 20.0},
#   {'x': 73.44882, 'y': 27.71684, 'r': 20.0},
#   {'x': 35.65863, 'y': 43.345715, 'r': 20.0},
#   {'x': 94.4971, 'y': 12.154995, 'r': 20.0},
#   {'x': 64.595135, 'y': 34.78327, 'r': 20.0},
#   {'x': 10.44323, 'y': 18.54025, 'r': 20.0},
#   {'x': 7.76847, 'y': 43.27595, 'r': 20.0},
#   {'x': 95.92709, 'y': 54.202926, 'r': 20.0},
#   {'x': 49.437672, 'y': 97.29667, 'r': 20.0},
#   {'x': 21.779985, 'y': 37.899125, 'r': 20.0},
#   {'x': 39.58443, 'y': 28.150345, 'r': 20.0},
#   {'x': 50.337118, 'y': 13.87323, 'r': 20.0},
#   {'x': 51.725585, 'y': 96.536445, 'r': 20.0},
#   {'x': 55.7501, 'y': 90.920415, 'r': 20.0},
#   {'x': 65.72564, 'y': 44.111465, 'r': 20.0},
#   {'x': 69.299455, 'y': 6.449115, 'r': 20.0},
#   {'x': 75.60926, 'y': 70.05143, 'r': 20.0},
#   {'x': 49.707097, 'y': 15.54357, 'r': 20.0},
#   {'x': 22.373755, 'y': 32.6144, 'r': 20.0},
#   {'x': 78.44886, 'y': 5.02628, 'r': 20.0},
#   {'x': 51.801592, 'y': 75.702955, 'r': 20.0},
#   {'x': 80.066985, 'y': 32.520545, 'r': 20.0},
#   {'x': 97.272905, 'y': 80.426715, 'r': 20.0},
#   {'x': 67.48261, 'y': 90.51293, 'r': 20.0},
#   {'x': 87.57797, 'y': 41.66484, 'r': 20.0},
#   {'x': 12.30828, 'y': 95.415795, 'r': 20.0},
#   {'x': 79.72973, 'y': 69.6285, 'r': 20.0},
#   {'x': 40.16046, 'y': 1.62977, 'r': 20.0},
#   {'x': 16.776285, 'y': 16.423415, 'r': 20.0},
#   {'x': 50.972003, 'y': 40.60627, 'r': 20.0},
#   {'x': 10.613375, 'y': 27.61233, 'r': 20.0},
#   {'x': 64.30468, 'y': 84.91, 'r': 20.0},
#   {'x': 49.796921, 'y': 18.777515, 'r': 20.0},
#   {'x': 89.661665, 'y': 37.28143, 'r': 20.0},
#   {'x': 32.35548, 'y': 77.08328, 'r': 20.0},
#   {'x': 21.800035, 'y': 44.699325, 'r': 20.0},
#   {'x': 23.602775, 'y': 87.83846, 'r': 20.0},
#   {'x': 61.04328, 'y': 37.44322, 'r': 20.0},
#   {'x': 38.950185, 'y': 86.058925, 'r': 20.0},
#   {'x': 58.59379, 'y': 93.155945, 'r': 20.0},
#   {'x': 51.719243, 'y': 33.03008, 'r': 20.0},
#   {'x': 86.845365, 'y': 25.906095, 'r': 20.0},
#   {'x': 25.954135, 'y': 17.869355, 'r': 20.0},
#   {'x': 34.695715, 'y': 0.250565, 'r': 20.0},
#   {'x': 74.234205, 'y': 84.088705, 'r': 20.0},
#   {'x': 27.85894, 'y': 70.297015, 'r': 20.0},
#   {'x': 40.48646, 'y': 81.157135, 'r': 20.0},
#   {'x': 74.17807, 'y': 43.76639, 'r': 20.0},
#   {'x': 7.79806, 'y': 41.063165, 'r': 20.0},
#   {'x': 33.93752, 'y': 71.055425, 'r': 20.0},
#   {'x': 31.22881, 'y': 79.877355, 'r': 20.0},
#   {'x': 15.17562, 'y': 59.299125, 'r': 20.0},
#   {'x': 95.62369, 'y': 24.314785, 'r': 20.0},
#   {'x': 93.997115, 'y': 11.43328, 'r': 20.0},
#   {'x': 98.425325, 'y': 63.29758, 'r': 20.0},
#   {'x': 59.88564, 'y': 90.256965, 'r': 20.0},
#   {'x': 57.48649, 'y': 24.517395, 'r': 20.0},
#   {'x': 86.016245, 'y': 7.495035, 'r': 20.0},
#   {'x': 43.88264, 'y': 75.9979, 'r': 20.0},
#   {'x': 24.567885, 'y': 37.86062, 'r': 20.0},
#   {'x': 39.724355, 'y': 52.657318, 'r': 20.0},
#   {'x': 27.03592, 'y': 58.11764, 'r': 20.0},
#   {'x': 20.9699, 'y': 7.87089, 'r': 20.0},
#   {'x': 89.544625, 'y': 11.14329, 'r': 20.0},
#   {'x': 65.23767, 'y': 90.033385, 'r': 20.0},
#   {'x': 23.159665, 'y': 94.99055, 'r': 20.0},
#   {'x': 84.61874, 'y': 44.121625, 'r': 20.0},
#   {'x': 49.200624, 'y': 76.95068, 'r': 20.0},
#   {'x': 83.48933, 'y': 38.25693, 'r': 20.0}],
#  'carrabs2020_upper_bound': 246.6830544811029,
#  'origin': 'https://github.com/CerroneCarmine/CETSP/tree/master'}
